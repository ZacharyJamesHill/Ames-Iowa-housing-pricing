# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dsi-us-10-project-2-regression-challenge-publicleaderboard.csv')

with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#       TeamId              TeamName       SubmissionDate         Score
# 0    4152942        Adi Bronshtein  2019-12-19 19:40:14  8.731062e+04
# 1    4209091     Noah Christiansen  2020-01-03 18:24:23  5.061959e+04
# 2    4209209                S.U.T.  2020-01-03 21:03:04  8.731066e+04
# 3    4209545        Joe Fitzgerald  2020-01-03 21:03:05  1.169981e+05
# 4    4209538            Tri Nguyen  2020-01-03 21:03:09  8.731066e+04
# 5    4209554         Paul McKinley  2020-01-03 21:03:13  8.731066e+04
# 6    4209536           Libin Huang  2020-01-03 21:03:14  8.731066e+04
# 7    4209604       Drew Dellarocco  2020-01-03 21:03:17  8.731066e+04
# 8    4209551          Elijah Curme  2020-01-03 21:03:26  8.731066e+04
# 9    4209541          Soojung Choi  2020-01-03 21:03:35  8.731066e+04
# 10   4209517        Robert Becotte  2020-01-03 21:03:41  8.731066e+04
# 11   4209546       MatthewBMurrell  2020-01-03 21:03:45  8.731066e+04
# ...

# %%
df = df[['TeamName', 'Score']]
df.head()
# Out:
#             TeamName         Score
# 0     Adi Bronshtein   87310.62061
# 1  Noah Christiansen   50619.58889
# 2             S.U.T.   87310.66057
# 3     Joe Fitzgerald  116998.11959
# 4         Tri Nguyen   87310.66057

# %%
bos = '@Rob @SJ @Elijah Curme @Drew Dellarocco - BOS @Rose Dennis @Joe @seflaherty @Oliver H. @Zach(he/his) @Libin Huang (he/him) - BOS @Elizabeth - BOS @Nick (he/him) - BOS @Yelena Nevel (she/her) - BOS @Tri Nguyen @Chris Powers - BOS@Matthew B Murrell @Paul McKinley - BOS'

# %%
bos = bos.replace('@', '')
bos = bos.replace('-', '')
bos = bos.replace('BOS', '')
bos = bos.replace('(she/her)', '')
bos = bos.replace('(he/him)', '')
bos = bos.replace(' ', ',')

bos = 'Rob,SJ,Elijah Curme,Drew Dellarocco,Rose Dennis,Joe,Sean Flaherty,Oliver H.,Zach,Libin Huang,Elizabeth,Nick,Yelena Nevel,Tri Nguyen,Chris Powers,Matthew B Murrell,Paul McKinley'

# %%
bos = bos.split(',')

# %%
bos = ['Elijah Curme',
 'Drew Dellarocco',
 'Rose Dennis',
 'Oliver Hernandez',
 'Zachary Hill (BOS)',
 'Libin Huang',
 'Elizabeth Jafek',
 'Nicholas Jin',
 'Yelena Nevel',
 'Tri Nguyen',
 'Christopher Powers',
 'mzavar',
 'Paul McKinley',
 'Robert Becotte',
 'Priv757',
 'Soojung Choi',
 'Joe Fitzgerald',
 'Sean Frey']

# %%
len(bos)
# Out:
# 18

# %%
df[df['Score'] <= 87311].mean()
# Out:
# Score    35997.248246
# dtype: float64

# %%
bos_scores = []

for i in bos:
 
    bos_scores.append(df.loc[df['TeamName'] == i, 'Score'])

# %%
bos_scores = [min(val) for val in bos_scores if len(val) > 0]

# %%
len(bos_scores)
# Out:
# 18

# %%
np.mean(bos_scores)
# Out:
# 26875.889858333332
